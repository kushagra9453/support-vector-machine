#        -9.12493632, -9.07897646, -9.03165312, -8.98294476, -8.93282873,
#        -8.88128118, -8.82827705, -8.77378994, -8.71779204, -8.66025404])

# %%
x1 = np.linspace(-5.0, 5.0, 100)
y1 = np.sqrt(5**2 - x1**2)
y1=np.hstack([y1,-y1])
x1=np.hstack([x1,-x1])

# %%
plt.scatter(y,x)
plt.scatter(y1,x1)

# %%
np.vstack([y,x]).T
# Out:
# array([[ 8.66025404, -5.        ],
#        [ 8.71779204, -4.8989899 ],
#        [ 8.77378994, -4.7979798 ],
#        [ 8.82827705, -4.6969697 ],
#        [ 8.88128118, -4.5959596 ],
#        [ 8.93282873, -4.49494949],
#        [ 8.98294476, -4.39393939],
#        [ 9.03165312, -4.29292929],
#        [ 9.07897646, -4.19191919],
#        [ 9.12493632, -4.09090909],
#        [ 9.16955321, -3.98989899],
#        [ 9.21284664, -3.88888889],
#        [ 9.25483518, -3.78787879],
#        [ 9.29553652, -3.68686869],
#        [ 9.3349675 , -3.58585859],
#        [ 9.37314414, -3.48484848],
#        [ 9.41008171, -3.38383838],
#        [ 9.44579475, -3.28282828],
#        [ 9.4802971 , -3.18181818],
#        [ 9.51360192, -3.08080808],
#        [ 9.54572176, -2.97979798],
#        [ 9.57666854, -2.87878788],
#        [ 9.60645359, -2.77777778],
#        [ 9.63508769, -2.67676768],
#        [ 9.66258107, -2.57575758],
#        [ 9.68894344, -2.47474747],
#        [ 9.714184  , -2.37373737],
#        [ 9.73831149, -2.27272727],
#        [ 9.76133416, -2.17171717],
#        [ 9.7832598 , -2.07070707],
#        [ 9.80409577, -1.96969697],
#        [ 9.82384901, -1.86868687],
#        [ 9.84252604, -1.76767677],
#        [ 9.86013297, -1.66666667],
#        [ 9.87667553, -1.56565657],
#        [ 9.89215905, -1.46464646],
#        [ 9.90658851, -1.36363636],
#        [ 9.91996849, -1.26262626],
#        [ 9.93230325, -1.16161616],
#        [ 9.94359667, -1.06060606],
#        [ 9.9538523 , -0.95959596],
#        [ 9.96307334, -0.85858586],
#        [ 9.97126266, -0.75757576],
#        [ 9.9784228 , -0.65656566],
#        [ 9.98455598, -0.55555556],
#        [ 9.98966408, -0.45454545],
#        [ 9.99374868, -0.35353535],
#        [ 9.99681104, -0.25252525],
#        [ 9.99885209, -0.15151515],
#        [ 9.99987246, -0.05050505],
#        [ 9.99987246,  0.05050505],
#        [ 9.99885209,  0.15151515],
#        [ 9.99681104,  0.25252525],
#        [ 9.99374868,  0.35353535],
#        [ 9.98966408,  0.45454545],
#        [ 9.98455598,  0.55555556],
#        [ 9.9784228 ,  0.65656566],
#        [ 9.97126266,  0.75757576],
#        [ 9.96307334,  0.85858586],
#        [ 9.9538523 ,  0.95959596],
#        [ 9.94359667,  1.06060606],
#        [ 9.93230325,  1.16161616],
#        [ 9.91996849,  1.26262626],
#        [ 9.90658851,  1.36363636],
#        [ 9.89215905,  1.46464646],
#        [ 9.87667553,  1.56565657],
#        [ 9.86013297,  1.66666667],
#        [-9.99885209,  0.15151515],
#        [-9.99987246,  0.05050505],
#        [-9.99987246, -0.05050505],
#        [-9.99885209, -0.15151515],
#        [-9.99681104, -0.25252525],
#        [-9.99374868, -0.35353535],
#        [-9.98966408, -0.45454545],
#        [-9.98455598, -0.55555556],
#        [-9.9784228 , -0.65656566],
#        [-9.97126266, -0.75757576],
#        [-9.96307334, -0.85858586],
#        [-9.9538523 , -0.95959596],
#        [-9.94359667, -1.06060606],
#        [-9.93230325, -1.16161616],
#        [-9.91996849, -1.26262626],
#        [-9.90658851, -1.36363636],
#        [-9.89215905, -1.46464646],
#        [-9.87667553, -1.56565657],
#        [-9.86013297, -1.66666667],
#        [-9.84252604, -1.76767677],
#        [-9.82384901, -1.86868687],
#        [-9.80409577, -1.96969697],
#        [-9.7832598 , -2.07070707],
#        [-9.76133416, -2.17171717],
#        [-9.73831149, -2.27272727],
#        [-9.714184  , -2.37373737],
#        [-9.68894344, -2.47474747],
#        [-9.66258107, -2.57575758],
#        [-9.63508769, -2.67676768],
#        [-9.60645359, -2.77777778],
#        [-9.57666854, -2.87878788],
#        [-9.54572176, -2.97979798],
#        [-9.51360192, -3.08080808],
#        [-9.4802971 , -3.18181818],
#        [-9.44579475, -3.28282828],
#        [-9.41008171, -3.38383838],
#        [-9.37314414, -3.48484848],
#        [-9.3349675 , -3.58585859],
#        [-9.29553652, -3.68686869],
#        [-9.25483518, -3.78787879],
#        [-9.21284664, -3.88888889],
#        [-9.16955321, -3.98989899],
#        [-9.12493632, -4.09090909],
#        [-9.07897646, -4.19191919],
#        [-9.03165312, -4.29292929],
#        [-8.98294476, -4.39393939],
#        [-8.93282873, -4.49494949],
#        [-8.88128118, -4.5959596 ],
#        [-8.82827705, -4.6969697 ],
#        [-8.77378994, -4.7979798 ],
#        [-8.71779204, -4.8989899 ],
#        [-8.66025404, -5.        ]])

# %%
import pandas as pd

df1 = pd.DataFrame(np.vstack([y,x]).T, columns=['X1','X2'])
df1['Y'] = 0

df2 = pd.DataFrame(np.vstack([y1,x1]).T, columns=['X1','X2'])
df2['Y'] = 1

df = pd.concat([df1, df2])   # FIXED LINE

df.head(5)
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
### Independent and Dependent features
X = df.iloc[:, :2]  
y = df.Y

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
Y_train
# Out:
# 3      0
# 18     0
# 2      1
# 50     1
# 74     1
#       ..
# 71     0
# 106    0
# 70     1
# 148    1
# 102    0
# Name: Y, Length: 320, dtype: int64

# %%
df['X1 squared']=df['X1']**2
df['X2 squared']=df['X2']**2
df['X1*X2']=df['X1']*df['X2']
df.head(5)
# Out:
#          X1       X2  Y  X1 squared  X2 squared      X1*X2
# 0  8.660254 -5.00000  0   75.000000   25.000000 -43.301270
# 1  8.717792 -4.89899  0   75.999898   24.000102 -42.708375
# 2  8.773790 -4.79798  0   76.979390   23.020610 -42.096467
# 3  8.828277 -4.69697  0   77.938476   22.061524 -41.466150
# 4  8.881281 -4.59596  0   78.877155   21.122845 -40.818009

# %%
X=df[['X1','X2','X1 squared','X2 squared','X1*X2']]
y=df[['Y']]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.25, 
                                                    random_state = 0)

# %%
X_train
# Out:
#            X1        X2  X1 squared  X2 squared      X1*X2
# 50   4.999745  0.050505   24.997449    0.002551   0.252512
# 63   9.906589  1.363636   98.140496    1.859504  13.508984
# 112 -3.263736  3.787879   10.651974   14.348026 -12.362637
# 159 -9.953852 -0.959596   99.079176    0.920824   9.551676
# 83   3.680983  3.383838   13.549638   11.450362  12.455852
# ..        ...       ...         ...         ...        ...
# 123 -4.223140  2.676768   17.834915    7.165085 -11.304366
# 192 -9.031653 -4.292929   81.570758   18.429242  38.772248
# 117 -9.445795  3.282828   89.223038   10.776962 -31.008922
# 47   9.996811 -0.252525   99.936231    0.063769  -2.524447
# 172 -9.738311 -2.272727   94.834711    5.165289  22.132526
#
# [300 rows x 5 columns]

# %%
import plotly.express as px
fig = px.scatter_3d(df, x='X1', y='X2', z='X1*X2',
              color='Y')
fig.show()

# %%
fig = px.scatter_3d(df, x='X1_Square', y='X1_Square', z='X1*X2',
              color='Y')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 fig = px.scatter_3d(df, x='X1_Square', y='X1_Square', z='X1*X2',
#       2               color='Y')
#       3 fig.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\express\_chart_types.py:791, in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, subtitle, template, width, height)
#     744 def scatter_3d(
#     745     data_frame=None,
#     746     x=None,
#    (...)    785     height=None,
#     786 ) -> go.Figure:
#     787     """
#     788     In a 3D scatter plot, each row of `data_frame` is represented by a
#     789     symbol mark in 3D space.
#     790     """
# --> 791     return make_figure(args=locals(), constructor=go.Scatter3d)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\express\_core.py:2511, in make_figure(args, constructor, trace_patch, layout_patch)
#    2508 layout_patch = layout_patch or {}
#    2509 apply_default_cascade(args, constructor=constructor)
# -> 2511 args = build_dataframe(args, constructor)
#    2512 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2513     args = process_dataframe_hierarchy(args)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\express\_core.py:1757, in build_dataframe(args, constructor)
#    1754     args["color"] = None
#    1755 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1757 df_output, wide_id_vars = process_args_into_dataframe(
#    1758     args,
#    1759     wide_mode,
#    1760     var_name,
#    1761     value_name,
#    1762     is_pd_like,
#    1763     native_namespace,
#    1764 )
#    1765 df_output: nw.DataFrame
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#
# File ~\AppData\Roaming\Python\Python313\site-packages\plotly\express\_core.py:1358, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1356         if argument == "index":
#    1357             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1358         raise ValueError(err_msg)
#    1359 elif length and (actual_len := len(df_input)) != length:
#    1360     raise ValueError(
#    1361         "All arguments should have the same length. "
#    1362         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1369         )
#    1370     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['X1', 'X2', 'Y', 'X1 squared', 'X2 squared', 'X1*X2'] but received: X1_Square
